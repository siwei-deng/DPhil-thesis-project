# %%
import numba
import scanpy as sc
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
adata = ...
adata.X = adata.layers["logcounts"]

# %% [markdown]
# # Manual annotation

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 55122 × 31944
#     obs: 'Group', 'group', 'Subject', 'cellType', 'cellType2', 'subcluster', 'leiden_0.1', 'leiden_0.3', 'leiden_0.5', 'leiden_0.7', 'leiden_1', 'leiden_1.5', 'leiden_2', 'leiden_3'
#     var: 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'highly_variable_nbatches', 'highly_variable_intersection'
#     uns: 'hvg', 'umap', 'neighbors', 'pca', 'Subject_colors', 'leiden_0.1', 'leiden_0.3', 'leiden_0.5', 'leiden_0.7', 'leiden_1', 'leiden_1.5', 'leiden_2', 'leiden_3', 'dea_leiden_1', 'dea_leiden_1_filtered', 'dea_leiden_0.5', 'dea_leiden_0.5_filtered', 'dea_leiden_0.3', 'dea_leiden_0.3_filtered', 'dea_leiden_0.1', 'dea_leiden_0.1_filtered', 'dea_leiden_0.7', 'dea_leiden_0.7_filtered', 'dea_leiden_1.5', 'dea_leiden_1.5_filtered', 'dea_leiden_2', 'dea_leiden_2_filtered', 'dea_leiden_3', 'dea_leiden_3_filtered', 'leiden_0.3_colors'
#     obsm: 'X_umap', 'X_pca', 'Harmony'
#     layers: 'counts', 'logcounts'
# ...

# %%
sc.pl.umap(
    adata,
    color=["leiden_0.3"],
    legend_loc="on data",
    frameon=False,
    legend_fontweight="normal",
)

# %%
markers = ["LYVE1", "PROX1"]

sc.pl.umap(
    adata,
    color=markers,
    legend_loc="on data",
    frameon=False,
    cmap="Reds",
)
